# %% [markdown]
# <a href="https://colab.research.google.com/github/Aron-Onofrio/Cyclone/blob/main/Q_OrificePlate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dados da placa de Orifício

# %%
def velocidade(a, b, D, rho, mu, dH, Dt, Or):

  Dt = Dt*10**-3 #Diâmetro da tubulação
  Or = Or*10**-3  #Diâmetro do orifício
  beta = Or/Dt

  Ar_Dt = np.pi*Dt**2/4
  Ar_Or = np.pi*Or**2/4

  r2 = (Ar_Or/Ar_Dt)**2

  #Perda de Carga na placa
  #dH = np.linspace(0.01, 0.96, 20)
  dP = rho*g*dH

  #Velocidade Teórica
  Vt = np.sqrt(2*(dP)/(rho*(1-r2)))

  #Vazão mássica teórica
  mt = rho*Vt*Ar_Dt

  #Reynolds Máximo
  Re = rho*Vt*Dt/mu

  #Coeficiente de descarga
  C = 0.5959 + 0.0312*beta**2.1 - 0.184*beta**8 + 91.71*beta**2.5/Re**0.75

  #Coeficiente de vazão
  k = C/np.sqrt(1-beta**4)

  #Vazão Real
  mr = k*Ar_Dt*np.sqrt(2*rho*dP)

  #Vazão volumétrica
  v = mr/rho

  #velocidade Real
  vel = mr/(rho*Ar_Dt)

  #Velocidade na entrada
  VelEn = Ar_Dt*vel/(a*b)

  for i in range(len(dH)):
      print(f"Velocidade na Entrada do Ciclone é: {VelEn[i]:.4f} m/s")

  return VelEn

# %%
plt.plot(dH,velocidade(a, b, D, rho, mu, dH, Dt, Or))
plt.title("Velocidade na Entrada do Ciclone")
plt.xlabel("Altura Manométrica (m)")
plt.ylabel("Velocidade na Entrada do Ciclone (m/s)")
plt.show()
# Out:
# Velocidade na Entrada do Ciclone é: 0.7434 m/s
# Velocidade na Entrada do Ciclone é: 1.7708 m/s
# Velocidade na Entrada do Ciclone é: 2.3833 m/s
# Velocidade na Entrada do Ciclone é: 2.8655 m/s
# Velocidade na Entrada do Ciclone é: 3.2762 m/s
# Velocidade na Entrada do Ciclone é: 3.6402 m/s
# Velocidade na Entrada do Ciclone é: 3.9705 m/s
# Velocidade na Entrada do Ciclone é: 4.2749 m/s
# Velocidade na Entrada do Ciclone é: 4.5588 m/s
# Velocidade na Entrada do Ciclone é: 4.8258 m/s
# Velocidade na Entrada do Ciclone é: 5.0786 m/s
# Velocidade na Entrada do Ciclone é: 5.3193 m/s
# Velocidade na Entrada do Ciclone é: 5.5494 m/s
# Velocidade na Entrada do Ciclone é: 5.7703 m/s
# Velocidade na Entrada do Ciclone é: 5.9829 m/s
# Velocidade na Entrada do Ciclone é: 6.1881 m/s
# Velocidade na Entrada do Ciclone é: 6.3866 m/s
# Velocidade na Entrada do Ciclone é: 6.5792 m/s
# Velocidade na Entrada do Ciclone é: 6.7661 m/s
# Velocidade na Entrada do Ciclone é: 6.9480 m/s
